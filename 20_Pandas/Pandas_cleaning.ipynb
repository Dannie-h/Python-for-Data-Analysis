# %%
import pandas as pd

# %%
df = pd.read_csv('data_jobs.csv')

# %%
df.head(10)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 7         Data Engineer                                      Data Engineer
# 8      Business Analyst           Technology & Operations Business Analyst
# 9        Data Scientist                                  Data Scientist II
#
#                    job_location             job_via         job_schedule_type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_posted_date[0] #we can see that it's string
# Out:
# '2023-06-16 13:44:15'

# %%
type(df.job_posted_date[0])
# Out:
# str

# %%
pd.to_datetime(df.job_posted_date)
# Out:
# 0        2023-06-16 13:44:15
# 1        2023-01-14 13:18:07
# 2        2023-10-10 13:14:55
# 3        2023-07-04 13:01:41
# 4        2023-08-07 14:29:36
#                  ...
# 785736   2023-03-13 06:16:16
# 785737   2023-03-12 06:18:18
# 785738   2023-03-12 06:32:36
# 785739   2023-03-12 06:32:15
# 785740   2023-03-13 06:16:31
# Name: job_posted_date, Length: 785741, dtype: datetime64[ns]

# %%
# but it's not converted yet
type(df.job_posted_date[0])
# Out:
# str

# %%
#we need to reassign once we turn it into datetime
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_posted_date.dt.month
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_date, Length: 785741, dtype: int64

# %%
# create a new column in the df with the month
df['job_posted_month'] = df.job_posted_date.dt.month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.sort_values('job_posted_date', inplace = True) #inplace will apply the changes, like reassigning to the variable df

# %%
df.head(10)
# Out:
#             job_title_short                                  job_title  \
# 108804         Data Analyst                               Data Analyst
# 96906          Data Analyst                               Data Analyst
# 98438          Data Analyst                               Data Analyst
# 110290         Data Analyst                               Data Analyst
# 72158   Senior Data Analyst  Senior Data Analyst / Platform Experience
# 104526         Data Analyst                           Jr. Data Analyst
# 73376          Data Analyst                               Data Analyst
# 99184          Data Analyst                               Data Analyst
# 111440         Data Analyst                               Data Analyst
# 100002        Data Engineer               Data Engineer / Data Analyst
#
#              job_location            job_via job_schedule_type  \
# 108804       New York, NY  via CareerBuilder         Full-time
# ...

# %%
# for the analysis we are only interested in the annual salary:
# 1 - we will drop the hourly salary
# 2 - we will remore the nan values

#1

df.drop(labels='salary_hour_avg', axis=1, inplace=True)

# %%
df
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %%
df.dropna(subset=['salary_year_avg'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22003 entries, 108883 to 327439
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
# ...

# %% [markdown]
# ### Practice

# %% [markdown]
# Sort the DataFrame by salary_year_avg in descending order and display the first 10 rows.

# %%
df.sort_values('salary_year_avg', ascending=False, inplace=True)

# %%
df.head(10)
# Out:
#               job_title_short  \
# 554784         Data Scientist
# 665811  Senior Data Scientist
# 168402           Data Analyst
# 387378         Data Scientist
# 160521         Data Scientist
# 404932          Data Engineer
# 554140         Data Scientist
# 417241  Senior Data Scientist
# 618461  Senior Data Scientist
# 474325         Data Scientist
#
#                                                 job_title  \
# 554784                                     Data Scientist
# 665811                              Senior Data Scientist
# 168402                                       Data Analyst
# 387378  Geographic Information Systems Analyst - GIS A...
# 160521              Staff Data Scientist/Quant Researcher
# 404932               Hybrid - Data Engineer - Up to $600k
# 554140          Staff Data Scientist - Business Analytics
# 417241                              Senior Data Scientist
# 618461                         VP Data Science & Research
# ...

# %% [markdown]
# Create a new column is_remote that indicates whether the job is remote (True) or not (False) based on the job_work_from_home column.

# %%
df['is_remote'] = df['job_work_from_home']

# %%
df.head()
# Out:
#               job_title_short  \
# 554784         Data Scientist
# 665811  Senior Data Scientist
# 168402           Data Analyst
# 387378         Data Scientist
# 160521         Data Scientist
#
#                                                 job_title  \
# 554784                                     Data Scientist
# 665811                              Senior Data Scientist
# 168402                                       Data Analyst
# 387378  Geographic Information Systems Analyst - GIS A...
# 160521              Staff Data Scientist/Quant Researcher
#
#                   job_location                        job_via  \
# 554784             Madison, SD  via Cooperative Career Center
# 665811  Pretoria, South Africa                     via Adzuna
# 168402                Anywhere               via Y Combinator
# 387378            New York, NY               via ZipRecruiter
# 160521                Anywhere                   via LinkedIn
#
# ...

# %% [markdown]
# Create a new column job_posted_year that extracts the year from the job_posted_date column and display the first 5 rows.

# %%
df['job_posted_year'] = df.job_posted_date.dt.year

# %%
df.head()
# Out:
#               job_title_short  \
# 554784         Data Scientist
# 665811  Senior Data Scientist
# 168402           Data Analyst
# 387378         Data Scientist
# 160521         Data Scientist
#
#                                                 job_title  \
# 554784                                     Data Scientist
# 665811                              Senior Data Scientist
# 168402                                       Data Analyst
# 387378  Geographic Information Systems Analyst - GIS A...
# 160521              Staff Data Scientist/Quant Researcher
#
#                   job_location                        job_via  \
# 554784             Madison, SD  via Cooperative Career Center
# 665811  Pretoria, South Africa                     via Adzuna
# 168402                Anywhere               via Y Combinator
# 387378            New York, NY               via ZipRecruiter
# 160521                Anywhere                   via LinkedIn
#
# ...
