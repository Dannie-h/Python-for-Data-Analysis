# %%
# Import libraries
import pandas as pd

# Read the file
df = pd.read_csv("D:/Python/Luke Barousse course/Python-for-Data-Analysis/20_Pandas/data_jobs.csv")

# Cleanup job posted date
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# ### Sample method
# - returns a random sample of items from an axis of object

# %%
df.sample()
# Out:
#        job_title_short      job_title job_location           job_via  \
# 185269   Data Engineer  Data Engineer       Canada  via BeBee Canada
#
#        job_schedule_type  job_work_from_home search_location  \
# 185269         Full-time               False          Canada
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 185269 2023-11-16 15:13:03                   True                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 185269      Canada         NaN              NaN              NaN
#
#                           company_name  \
# 185269  Opus Recruitment Solutions Ltd
#
#                                                job_skills  \
# 185269  ['sql', 'python', 'c#', 'powershell', 'azure',...
#
#                                           job_type_skills
# 185269  {'cloud': ['azure', 'databricks'], 'other': ['...

# %%
df.sample(10)
# Out:
#             job_title_short  \
# 385429         Data Analyst
# 430897        Data Engineer
# 762496  Senior Data Analyst
# 686151         Data Analyst
# 182108  Senior Data Analyst
# 658404         Data Analyst
# 355163     Business Analyst
# 573589         Data Analyst
# 402503        Data Engineer
# 204106         Data Analyst
#
#                                                 job_title  \
# 385429                  Data Analytics Internship in pune
# 430897  Data Engineer Semi Senior Full time Kabeli Remoto
# 762496  Senior Data Analyst /MNC IT Service Provider/ ...
# 686151                                       Data Analyst
# 182108                       Senior Business Data Analyst
# 658404                                       DATA ANALYST
# 355163              Senior BI Engineer - PowerBI & Looker
# 573589                          Sr. Research Data Analyst
# 402503                                      Data Engineer
# 204106                              Business/Data Analyst
#
# ...

# %%
# if we want the same results to be returned every time, we can set a random state

df.sample(10, random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# ...

# %% [markdown]
# ### Copy
# - thinking of how we previsouly assigned a new data frame and made some modifications, the initial dataframe will end up changing as well

# %%
df_altered = df.copy()

# %%
id(df_altered) == id(df) # now the df_altered is a completely different df and any changes made in df_altered won't affect the original df
# Out:
# False

# %% [markdown]
# ### Practice

# %% [markdown]
# Create a copy of the DataFrame and drop rows where the salary_year_avg column has missing values. Display the first 5 rows of the cleaned DataFrame.

# %%
df_drop_na = df.copy()

# %%
df_drop_na = df_drop_na.dropna(subset = ['salary_year_avg'])

# %%
df_drop_na.head(5)
# Out:
#     job_title_short                                job_title  \
# 28   Data Scientist                      CRM Data Specialist
# 77    Data Engineer                            Data Engineer
# 92    Data Engineer  Remote - Data Engineer - Permanent - W2
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                                 job_location          job_via  \
# 28   San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                             Arlington, VA     via LinkedIn
# 92                                  Anywhere     via LinkedIn
# 100                        Mountain View, CA     via LinkedIn
# 109                                 Anywhere       via Get.It
#
#     job_schedule_type  job_work_from_home            search_location  \
# 28          Full-time               False                 Costa Rica
# 77          Full-time               False                      Sudan
# ...

# %% [markdown]
# Create a new DataFrame that is a random sample of 10% of the original DataFrame. Display the first 5 rows of the sampled DataFrame.

# %%
sample_df = df.sample(frac=0.2)
sample_df.head(5)
# Out:
#             job_title_short  \
# 222341         Data Analyst
# 116619       Data Scientist
# 202787        Data Engineer
# 240173         Data Analyst
# 336085  Senior Data Analyst
#
#                                                 job_title  \
# 222341                             Data Analytics Manager
# 116619                     Senior Analyst/ Data Scientist
# 202787                                   Developer (Data)
# 240173        Business Systems Analyst III, Data Analysis
# 336085  Senior Manager - Business Analytics | Data Str...
#
#                        job_location            job_via job_schedule_type  \
# 222341              Dublin, Ireland  via BeBee Ireland         Full-time
# 116619  Bengaluru, Karnataka, India    via BeBee India         Full-time
# 202787   Johannesburg, South Africa    via Trabajo.org         Full-time
# 240173               Schaumburg, IL   via ZipRecruiter         Full-time
# ...

# %% [markdown]
# Create a copy of the original DataFrame and fill in missing values in the salary_year_avg column with the median salary. Display the first 5 rows of the altered DataFrame.

# %%
df_filled = df.copy()

# %%
median_salary = df_filled['salary_year_avg'].median()

# %%
median_salary
# Out:
# 115000.0

# %%
df_filled['salary_year_avg'] = df_filled['salary_year_avg'].fillna(median_salary)

# %%
df_filled
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...
