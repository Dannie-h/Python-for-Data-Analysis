# %% [markdown]
# #### Merging DataFrames

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Loading data

df = pd.read_csv("D:/Python/Luke Barousse course/Python-for-Data-Analysis/20_Pandas/data_jobs.csv")

# data cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# ##### Practice with a small example

# %%
job_data = {
    'job_id': [1,  2, 3, 4, 5],
    'job_title': ['Data Scientist', 'Software Engineer', 'Product Manager', 'Marketing Director', 'HR Manager'],
    'company_name': ['Google', 'Microsoft', 'Apple', 'Nike', 'Starbucks'],
    'job_location': ['Mountain View, CA', 'Redmond, WA', 'Cupertino, CA', 'Beaverton, OR', 'Seattle, WA']
}

company_data ={
    'company_name': ['Google', 'Microsoft', 'Apple', 'Nike', 'Starbucks'],
    'industry': ['Technology', 'Technology', 'Technology', 'Apparel', 'Food & Beverage'],
    'company_size': ['100,000+', '100,000+', '100,000+', '75,000+', '346,000+']
}

df_jobs = pd.DataFrame(job_data)
df_companies = pd.DataFrame(company_data)

# %%
df_jobs
# Out:
#    job_id           job_title company_name       job_location
# 0       1      Data Scientist       Google  Mountain View, CA
# 1       2   Software Engineer    Microsoft        Redmond, WA
# 2       3     Product Manager        Apple      Cupertino, CA
# 3       4  Marketing Director         Nike      Beaverton, OR
# 4       5          HR Manager    Starbucks        Seattle, WA

# %%
df_companies
# Out:
#   company_name         industry company_size
# 0       Google       Technology     100,000+
# 1    Microsoft       Technology     100,000+
# 2        Apple       Technology     100,000+
# 3         Nike          Apparel      75,000+
# 4    Starbucks  Food & Beverage     346,000+

# %%
# Merge the two datasets
# df_jobs is on the left and we're joining the df_companies which is on the right, both datasets have the same name of company_name

df_jb_company = df_jobs.merge(df_companies, on = 'company_name')

# %%
df_jb_company
# Out:
#    job_id           job_title company_name       job_location  \
# 0       1      Data Scientist       Google  Mountain View, CA
# 1       2   Software Engineer    Microsoft        Redmond, WA
# 2       3     Product Manager        Apple      Cupertino, CA
# 3       4  Marketing Director         Nike      Beaverton, OR
# 4       5          HR Manager    Starbucks        Seattle, WA
#
#           industry company_size
# 0       Technology     100,000+
# 1       Technology     100,000+
# 2       Technology     100,000+
# 3          Apparel      75,000+
# 4  Food & Beverage     346,000+

# %% [markdown]
# Let's go back to our data. </br>
# we will use the pivot table we created in the previous lesson.

# %%
df_US = df[df['job_country'] == 'United States'].copy()
df_US['job_posted_month'] = df_US['job_posted_date'].dt.strftime('%B')

# %%
df_US_pivot = df_US.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')

# %%
df_US_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# April                          565              40          6049
# August                         903              39          6634
# December                       648              40          3979
# February                       447              24          6124
# January                        527              36          8494
# July                           581              39          5201
# June                           446              32          5683
# March                          438              19          6218
# May                            279              20          4993
# November                       719              36          4531
# October                        932              48          5271
# September                      897              50          4639
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_US_pivot.reset_index(inplace=True)
df_US_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 0                          April               565              40
# 1                         August               903              39
# 2                       December               648              40
# 3                       February               447              24
# 4                        January               527              36
# 5                           July               581              39
# 6                           June               446              32
# 7                          March               438              19
# 8                            May               279              20
# 9                       November               719              36
# 10                       October               932              48
# 11                     September               897              50
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
df_US_pivot['job_posted_month_number'] = pd.to_datetime(df_US_pivot['job_posted_month'], format='%B').dt.month
df_US_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 0                          April               565              40
# 1                         August               903              39
# 2                       December               648              40
# 3                       February               447              24
# 4                        January               527              36
# 5                           July               581              39
# 6                           June               446              32
# 7                          March               438              19
# 8                            May               279              20
# 9                       November               719              36
# 10                       October               932              48
# 11                     September               897              50
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
df_US_pivot.sort_values('job_posted_month_number', inplace=True)

# %%
df_US_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 4                        January               527              36
# 3                       February               447              24
# 7                          March               438              19
# 0                          April               565              40
# 8                            May               279              20
# 6                           June               446              32
# 5                           July               581              39
# 1                         August               903              39
# 11                     September               897              50
# 10                       October               932              48
# 9                       November               719              36
# 2                       December               648              40
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
df_US_pivot.set_index('job_posted_month', inplace=True)

df_US_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_US_pivot = df_US_pivot.drop(columns='job_posted_month_number')

# %%
df_US_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %% [markdown]
# We want to compare to software development jobs which we have in a different database

# %%
df_US_software = pd.read_csv('software_jobs.csv')

# %%
df_US_software
# Out:
#    job_posted_month  Front-End Developer  Back-End Developer  \
# 0           January                13619                9827
# 1          February                11456                9116
# 2             March                11102                8178
# 3             April                14037                9209
# 4               May                12126                8864
# 5              June                12003                8065
# 6              July                11914                8061
# 7            August                11571                8191
# 8         September                14016                8447
# 9           October                11419                8476
# 10         November                13771                9034
# 11         December                14033                9232
#
#     Full-Stack Developer  UI/UX Designer
# 0                   5108            4348
# 1                   7298            4284
# 2                   5814            4159
# ...

# %%
# we have an index in the software jobs whereas in the data jobs we have the job_posted_month as index
# we can either reset the index as above, or we can set the index when we're reading the file
df_US_software = pd.read_csv('software_jobs.csv', index_col ='job_posted_month')
df_US_software
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# ...

# %%
# we are going to merge the two datasets now
df_US_merged = df_US_pivot.merge(df_US_software, on='job_posted_month')
df_US_merged
# Out:
#                   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
#                   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %% [markdown]
# We want to plot the top 5 jobs count in the year and see how they trend over time.

# %%
top_5 = df_US_merged.sum().sort_values(ascending=False).head(5)
top_5
# Out:
# Front-End Developer     151067
# Back-End Developer      104700
# Full-Stack Developer     75873
# Data Analyst             67816
# Data Scientist           58830
# dtype: int64

# %%
top_5 = top_5.index.to_list

# %%
# we can write all on the same line and use parenthesis to split it on multiple rows to increase readability
top_5 = (
    df_US_merged
    .sum()
    .sort_values(ascending=False)
    .head(5)
    .index # get the inted of the top 5
    .to_list() # put the top 5 in a list
)

# %%
df_US_merged[top_5].plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
# let's clean the messy chart
df_US_merged[top_5].plot(kind='line')
plt.title('Montly Job Postings for Top 5 Tech Jobs in the US')
plt.xlabel('2023')
plt.ylabel('Job Count')
plt.ylim(0, 20_000)
plt.legend()
plt.show()
