# %%
 # import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Loading data

df = pd.read_csv("D:/Python/Luke Barousse course/Python-for-Data-Analysis/20_Pandas/data_jobs.csv")

# data cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# We want to export the Q1 postings.

# %%
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')

months = df['job_posted_month'].unique()

dict_months =  {month:df[df['job_posted_month'] == month] for month in months}

df_q1 = pd.concat([dict_months['Jan'], dict_months['Feb'], dict_months['Mar']], ignore_index=True)

df_q1
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
#                                  job_location                    job_via  \
# 0                Guadalajara, Jalisco, Mexico           via BeBee México
# 1                           Zaventem, Belgium         via BeBee Belgique
# 2                              Fort Worth, TX               via LinkedIn
# 3                               San Mateo, CA               via LinkedIn
# 4       São Paulo, State of São Paulo, Brazil                  via BeBee
# ...                                       ...                        ...
# 220479                              Singapura        melalui Trabajo.org
# 220480                     Bad Rodach, Jerman  melalui BeBee Deutschland
# 220481                               Malaysia           melalui Ricebowl
# 220482    Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 220483                                  India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home            search_location  \
# 0              Full-time               False                     Mexico
# 1              Full-time               False                    Belgium
# 2              Full-time               False       Texas, United States
# 3              Full-time               False  California, United States
# 4              Full-time               False                     Brazil
# ...                  ...                 ...                        ...
# 220479   Pekerjaan tetap               False                  Singapore
# 220480   Pekerjaan tetap               False                    Germany
# 220481   Pekerjaan tetap               False                   Malaysia
# 220482   Pekerjaan tetap               False                      Sudan
# 220483   Pekerjaan tetap               False                      India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-01-14 13:18:07                  False                 False
# 1      2023-01-31 13:53:38                  False                 False
# 2      2023-01-25 13:24:01                  False                 False
# 3      2023-01-28 13:07:30                  False                  True
# 4      2023-01-03 23:02:27                  False                 False
# ...                    ...                    ...                   ...
# 220479 2023-03-13 06:16:16                  False                 False
# 220480 2023-03-12 06:18:18                  False                 False
# 220481 2023-03-12 06:32:36                  False                 False
# 220482 2023-03-12 06:32:15                  False                 False
# 220483 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0              Mexico         NaN              NaN              NaN
# 1             Belgium         NaN              NaN              NaN
# 2       United States         NaN              NaN              NaN
# 3       United States         NaN              NaN              NaN
# 4              Brazil         NaN              NaN              NaN
# ...               ...         ...              ...              ...
# 220479      Singapore         NaN              NaN              NaN
# 220480        Germany         NaN              NaN              NaN
# 220481       Malaysia         NaN              NaN              NaN
# 220482          Sudan         NaN              NaN              NaN
# 220483          India         NaN              NaN              NaN
#
#                               company_name  \
# 0               Hewlett Packard Enterprise
# 1                                 Devoteam
# 2                           Programmers.io
# 3                                  Verkada
# 4                                     Mars
# ...                                    ...
# 220479  CAREERSTAR INTERNATIONAL PTE. LTD.
# 220480                    HABA FAMILYGROUP
# 220481               Lendlease Corporation
# 220482                         Capital One
# 220483                              Trigyn
#
#                                                job_skills  \
# 0       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 1       ['r', 'python', 'sql', 'pandas', 'numpy', 'sci...
# 2                                       ['sql', 'python']
# 3                      ['sql', 'python', 'aws', 'looker']
# 4                              ['python', 'sql', 'azure']
# ...                                                   ...
# 220479  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 220480                     ['sas', 'sas', 'sql', 'excel']
# 220481                            ['powerpoint', 'excel']
# 220482  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 220483                                    ['aws', 'flow']
#
#                                           job_type_skills job_posted_month
# 0       {'analyst_tools': ['power bi', 'tableau'], 'pr...              Jan
# 1       {'libraries': ['pandas', 'numpy', 'scikit-lear...              Jan
# 2                      {'programming': ['sql', 'python']}              Jan
# 3       {'analyst_tools': ['looker'], 'cloud': ['aws']...              Jan
# 4       {'cloud': ['azure'], 'programming': ['python',...              Jan
# ...                                                   ...              ...
# 220479  {'os': ['linux', 'unix'], 'other': ['kubernete...              Mar
# 220480  {'analyst_tools': ['sas', 'excel'], 'programmi...              Mar
# 220481         {'analyst_tools': ['powerpoint', 'excel']}              Mar
# 220482  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...              Mar
# 220483              {'cloud': ['aws'], 'other': ['flow']}              Mar
#
# [220484 rows x 18 columns]

# %% [markdown]
# ### Different ways of exporting the data

# %%
df_q1.head().to_clipboard(sep=",")

# %% [markdown]
# ,job_title_short,job_title,job_location,job_via,job_schedule_type,job_work_from_home,search_location,job_posted_date,job_no_degree_mention,job_health_insurance,job_country,salary_rate,salary_year_avg,salary_hour_avg,company_name,job_skills,job_type_skills,job_posted_month
# 0,Data Analyst,Data Analyst,"Guadalajara, Jalisco, Mexico",via BeBee México,Full-time,False,Mexico,2023-01-14 13:18:07,False,False,Mexico,,,,Hewlett Packard Enterprise,"['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']","{'analyst_tools': ['power bi', 'tableau'], 'programming': ['r', 'python', 'sql', 'nosql']}",Jan
# 1,Data Scientist,Data Scientist,"Zaventem, Belgium",via BeBee Belgique,Full-time,False,Belgium,2023-01-31 13:53:38,False,False,Belgium,,,,Devoteam,"['r', 'python', 'sql', 'pandas', 'numpy', 'scikit-learn', 'matplotlib', 'hadoop', 'spark']","{'libraries': ['pandas', 'numpy', 'scikit-learn', 'matplotlib', 'hadoop', 'spark'], 'programming': ['r', 'python', 'sql']}",Jan
# 2,Data Engineer,Data Engineer,"Fort Worth, TX",via LinkedIn,Full-time,False,"Texas, United States",2023-01-25 13:24:01,False,False,United States,,,,Programmers.io,"['sql', 'python']","{'programming': ['sql', 'python']}",Jan
# 3,Data Engineer,Data Engineer,"San Mateo, CA",via LinkedIn,Full-time,False,"California, United States",2023-01-28 13:07:30,False,True,United States,,,,Verkada,"['sql', 'python', 'aws', 'looker']","{'analyst_tools': ['looker'], 'cloud': ['aws'], 'programming': ['sql', 'python']}",Jan
# 4,Data Scientist,Data Scientist,"São Paulo, State of São Paulo, Brazil",via BeBee,Full-time,False,Brazil,2023-01-03 23:02:27,False,False,Brazil,,,,Mars,"['python', 'sql', 'azure']","{'cloud': ['azure'], 'programming': ['python', 'sql']}",Jan

# %%
df_q1.to_csv('quarter_1.csv')

# %%
pd.read_csv('quarter_1.csv', index_col=0)
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
#                                  job_location                    job_via  \
# 0                Guadalajara, Jalisco, Mexico           via BeBee México
# 1                           Zaventem, Belgium         via BeBee Belgique
# 2                              Fort Worth, TX               via LinkedIn
# 3                               San Mateo, CA               via LinkedIn
# 4       São Paulo, State of São Paulo, Brazil                  via BeBee
# ...                                       ...                        ...
# 220479                              Singapura        melalui Trabajo.org
# 220480                     Bad Rodach, Jerman  melalui BeBee Deutschland
# 220481                               Malaysia           melalui Ricebowl
# 220482    Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 220483                                  India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home            search_location  \
# 0              Full-time               False                     Mexico
# 1              Full-time               False                    Belgium
# 2              Full-time               False       Texas, United States
# 3              Full-time               False  California, United States
# 4              Full-time               False                     Brazil
# ...                  ...                 ...                        ...
# 220479   Pekerjaan tetap               False                  Singapore
# 220480   Pekerjaan tetap               False                    Germany
# 220481   Pekerjaan tetap               False                   Malaysia
# 220482   Pekerjaan tetap               False                      Sudan
# 220483   Pekerjaan tetap               False                      India
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0       2023-01-14 13:18:07                  False                 False
# 1       2023-01-31 13:53:38                  False                 False
# 2       2023-01-25 13:24:01                  False                 False
# 3       2023-01-28 13:07:30                  False                  True
# 4       2023-01-03 23:02:27                  False                 False
# ...                     ...                    ...                   ...
# 220479  2023-03-13 06:16:16                  False                 False
# 220480  2023-03-12 06:18:18                  False                 False
# 220481  2023-03-12 06:32:36                  False                 False
# 220482  2023-03-12 06:32:15                  False                 False
# 220483  2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0              Mexico         NaN              NaN              NaN
# 1             Belgium         NaN              NaN              NaN
# 2       United States         NaN              NaN              NaN
# 3       United States         NaN              NaN              NaN
# 4              Brazil         NaN              NaN              NaN
# ...               ...         ...              ...              ...
# 220479      Singapore         NaN              NaN              NaN
# 220480        Germany         NaN              NaN              NaN
# 220481       Malaysia         NaN              NaN              NaN
# 220482          Sudan         NaN              NaN              NaN
# 220483          India         NaN              NaN              NaN
#
#                               company_name  \
# 0               Hewlett Packard Enterprise
# 1                                 Devoteam
# 2                           Programmers.io
# 3                                  Verkada
# 4                                     Mars
# ...                                    ...
# 220479  CAREERSTAR INTERNATIONAL PTE. LTD.
# 220480                    HABA FAMILYGROUP
# 220481               Lendlease Corporation
# 220482                         Capital One
# 220483                              Trigyn
#
#                                                job_skills  \
# 0       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 1       ['r', 'python', 'sql', 'pandas', 'numpy', 'sci...
# 2                                       ['sql', 'python']
# 3                      ['sql', 'python', 'aws', 'looker']
# 4                              ['python', 'sql', 'azure']
# ...                                                   ...
# 220479  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 220480                     ['sas', 'sas', 'sql', 'excel']
# 220481                            ['powerpoint', 'excel']
# 220482  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 220483                                    ['aws', 'flow']
#
#                                           job_type_skills job_posted_month
# 0       {'analyst_tools': ['power bi', 'tableau'], 'pr...              Jan
# 1       {'libraries': ['pandas', 'numpy', 'scikit-lear...              Jan
# 2                      {'programming': ['sql', 'python']}              Jan
# 3       {'analyst_tools': ['looker'], 'cloud': ['aws']...              Jan
# 4       {'cloud': ['azure'], 'programming': ['python',...              Jan
# ...                                                   ...              ...
# 220479  {'os': ['linux', 'unix'], 'other': ['kubernete...              Mar
# 220480  {'analyst_tools': ['sas', 'excel'], 'programmi...              Mar
# 220481         {'analyst_tools': ['powerpoint', 'excel']}              Mar
# 220482  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...              Mar
# 220483              {'cloud': ['aws'], 'other': ['flow']}              Mar
#
# [220484 rows x 18 columns]

# %%
df_q1.to_excel('quarter_1.xlxs')
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# File c:\Users\hdcda\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1144, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1143 try:
# -> 1144     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1145     if engine == "auto":
#
# File c:\Users\hdcda\anaconda3\Lib\site-packages\pandas\_config\config.py:263, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     262 def __call__(self, *args, **kwds) -> T:
# --> 263     return self.__func__(*args, **kwds)
#
# File c:\Users\hdcda\anaconda3\Lib\site-packages\pandas\_config\config.py:135, in _get_option(pat, silent)
#     134 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 135     key = _get_single_key(pat, silent)
#     137     # walk the nested dict
#
# File c:\Users\hdcda\anaconda3\Lib\site-packages\pandas\_config\config.py:121, in _get_single_key(pat, silent)
#     120         _warn_if_deprecated(pat)
# --> 121     raise OptionError(f"No such keys(s): {repr(pat)}")
#     122 if len(keys) > 1:
#
# OptionError: No such keys(s): 'io.excel.xlxs.writer'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_q1.to_excel('quarter_1.xlxs')
#
# File c:\Users\hdcda\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\hdcda\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\hdcda\anaconda3\Lib\site-packages\pandas\core\generic.py:2374, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2361 from pandas.io.formats.excel import ExcelFormatter
#    2363 formatter = ExcelFormatter(
#    2364     df,
#    2365     na_rep=na_rep,
#    (...)
#    2372     inf_rep=inf_rep,
#    2373 )
# -> 2374 formatter.write(
#    2375     excel_writer,
#    2376     sheet_name=sheet_name,
#    2377     startrow=startrow,
#    2378     startcol=startcol,
#    2379     freeze_panes=freeze_panes,
#    2380     engine=engine,
#    2381     storage_options=storage_options,
#    2382 )
#
# File c:\Users\hdcda\anaconda3\Lib\site-packages\pandas\io\formats\excel.py:944, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     940     need_save = False
#     941 else:
#     942     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     943     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 944     writer = ExcelWriter(  # type: ignore[abstract]
#     945         writer, engine=engine, storage_options=storage_options
#     946     )
#     947     need_save = True
#     949 try:
#
# File c:\Users\hdcda\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1148, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1146             engine = get_default_engine(ext, mode="writer")
#    1147     except KeyError as err:
# -> 1148         raise ValueError(f"No engine for filetype: '{ext}'") from err
#    1150 if engine == "xlwt":
#    1151     xls_config_engine = config.get_option(
#    1152         "io.excel.xls.writer", silent=True
#    1153     )
#
# ValueError: No engine for filetype: 'xlxs'

# %%
# %conda install openpyxl
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\hdcda\anaconda3
#
#   added / updated specs:
#     - openpyxl
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.7.15  |       haa95532_0         127 KB
#     certifi-2025.8.3           |  py311haa95532_0         161 KB
#     ------------------------------------------------------------
#                                            Total:         288 KB
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2025.2.25-haa95532_0 --> 2025.7.15-haa95532_0
#   certifi                         2025.1.31-py311haa95532_0 --> 2025.8.3-py311haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# certifi-2025.8.3     | 161 KB    |            |   0%
#
# ca-certificates-2025 | 127 KB    |            |   0%
# certifi-2025.8.3     | 161 KB    | 9          |  10%
# certifi-2025.8.3     | 161 KB    | ########## | 100%
#
# ca-certificates-2025 | 127 KB    | #2         |  13%
#
# ca-certificates-2025 | 127 KB    | ########## | 100%
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.5.2
#   latest version: 25.7.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=25.7.0

# %%
df_q1.to_excel('quarter_1.xlsx')

# %% [markdown]
# #### Practice

# %% [markdown]
# Export the DataFrame to a CSV file named data_jobs_export.csv without including the index. Inspect the contents of the CSV exported.

# %%
df.to_csv('data_jobs_export.csv', index=False)

# %% [markdown]
# Filter the DataFrame to include only job postings with 'Data Scientist' in the job_title_short column.
# Export the filtered DataFrame to a CSV file named data_scientist_jobs.csv without including the index.
# Inspect that the CSV has been exported with the correct filtered data.

# %%
df_DS = df[df['job_title_short'] == 'Data Scientist'].copy()

# %%
df_DS.to_csv('data_scientist_jobs.csv', index=False)

# %%
pd.read_csv('data_scientist_jobs.csv')
# Out:
#        job_title_short                                          job_title  \
# 0       Data Scientist                                  Data Scientist II
# 1       Data Scientist                             Data Science Team Lead
# 2       Data Scientist                                     Data Scientist
# 3       Data Scientist                                     Data Scientist
# 4       Data Scientist  Stage - data scientist – génération ia de donn...
# ...                ...                                                ...
# 172281  Data Scientist                           Data Scientist -50065385
# 172282  Data Scientist                    Customer Master Data Specialist
# 172283  Data Scientist               Data Scientist- Hybrid Work Location
# 172284  Data Scientist                      Data Science Python modelling
# 172285  Data Scientist                                 Analytics Engineer
#
#                              job_location  \
# 0                                Anywhere
# 1                              Laurel, MD
# 2                Pune, Maharashtra, India
# 3                       Zaventem, Belgium
# 4              Asnières-sur-Seine, France
# ...                                   ...
# 172281                             Israel
# 172282  Makati, Metro Manila, Philippines
# 172283                         Dayton, OH
# 172284           Pune, Maharashtra, India
# 172285                             Jerman
#
#                                                   job_via job_schedule_type  \
# 0                                        via ZipRecruiter         Full-time
# 1       via APL Careers - Johns Hopkins University App...         Full-time
# 2                                              via Indeed         Full-time
# 3                                      via BeBee Belgique         Full-time
# 4                                            via Jobijoba         Full-time
# ...                                                   ...               ...
# 172281                                       via LinkedIn         Full-time
# 172282                                    via Trabajo.org         Full-time
# 172283                                    via Ai-Jobs.net         Full-time
# 172284                                       via LinkedIn         Full-time
# 172285                               melalui Startup Jobs   Pekerjaan tetap
#
#         job_work_from_home          search_location      job_posted_date  \
# 0                     True  New York, United States  2023-04-23 13:02:57
# 1                    False                  Georgia  2023-06-13 13:25:17
# 2                    False                    India  2023-04-26 13:20:12
# 3                    False                  Belgium  2023-01-31 13:53:38
# 4                    False                   France  2023-02-23 13:41:21
# ...                    ...                      ...                  ...
# 172281               False                   Israel  2023-01-30 06:36:07
# 172282               False              Philippines  2023-01-18 06:16:42
# 172283               False  Illinois, United States  2023-04-21 06:02:31
# 172284               False                    India  2023-01-16 06:12:27
# 172285               False                  Germany  2023-03-12 06:18:18
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 0                       False                 False  United States
# 1                       False                  True  United States
# 2                       False                 False          India
# 3                       False                 False        Belgium
# 4                       False                 False         France
# ...                       ...                   ...            ...
# 172281                  False                 False         Israel
# 172282                  False                 False    Philippines
# 172283                  False                  True  United States
# 172284                  False                 False          India
# 172285                  False                 False        Germany
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 0              NaN              NaN              NaN
# 1              NaN              NaN              NaN
# 2              NaN              NaN              NaN
# 3              NaN              NaN              NaN
# 4              NaN              NaN              NaN
# ...            ...              ...              ...
# 172281         NaN              NaN              NaN
# 172282         NaN              NaN              NaN
# 172283        year         157500.0              NaN
# 172284         NaN              NaN              NaN
# 172285         NaN              NaN              NaN
#
#                                     company_name  \
# 0                     Radwell International, LLC
# 1       Johns Hopkins Applied Physics Laboratory
# 2                              Bitwise Solutions
# 3                                       Devoteam
# 4                                Credit Agricole
# ...                                          ...
# 172281            Phoenix Holdings  קבוצת הפניקס
# 172282                                    Henkel
# 172283                                    Tenet3
# 172284                          Live Connections
# 172285                                    Planet
#
#                                                job_skills  \
# 0       ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# 1                                  ['go', 'apl', 'excel']
# 2       ['r', 'sql', 'python', 'scala', 'java', 'c++',...
# 3       ['r', 'python', 'sql', 'pandas', 'numpy', 'sci...
# 4                                                     NaN
# ...                                                   ...
# 172281                                            ['sql']
# 172282      ['vba', 'sap', 'word', 'powerpoint', 'excel']
# 172283                          ['python', 'matlab', 'r']
# 172284  ['python', 'sql', 'r', 'power bi', 'tableau', ...
# 172285  ['sql', 'bigquery', 'gdpr', 'git', 'gitlab', '...
#
#                                           job_type_skills job_posted_month
# 0       {'analyst_tools': ['excel'], 'cloud': ['azure'...              Apr
# 1       {'analyst_tools': ['excel'], 'programming': ['...              Jun
# 2       {'analyst_tools': ['tableau'], 'libraries': ['...              Apr
# 3       {'libraries': ['pandas', 'numpy', 'scikit-lear...              Jan
# 4                                                     NaN              Feb
# ...                                                   ...              ...
# 172281                           {'programming': ['sql']}              Jan
# 172282  {'analyst_tools': ['sap', 'word', 'powerpoint'...              Jan
# 172283         {'programming': ['python', 'matlab', 'r']}              Apr
# 172284  {'analyst_tools': ['power bi', 'tableau', 'wor...              Jan
# 172285  {'cloud': ['bigquery'], 'libraries': ['gdpr'],...              Mar
#
# [172286 rows x 18 columns]

# %% [markdown]
# Filter the DataFrame to include only job postings with 'New York, NY' in the job_location column.
# Export the filtered DataFrame to an Excel file named new_york_jobs.xlsx without including the index.
# Display the first 5 rows of the filtered DataFrame to confirm the export.

# %%
df_NY = df[df['job_location'] == 'New York, NY'].copy()
df_NY.head()
# Out:
#           job_title_short                                          job_title  \
# 13   Senior Data Engineer                               Senior Data Engineer
# 126         Data Engineer                                      Data Engineer
# 177  Senior Data Engineer                         Cyber Senior Data Engineer
# 230          Data Analyst  Financial Systems – Business Analyst/ Data Ana...
# 502          Data Analyst                             Reporting Data Analyst
#
#      job_location                   job_via job_schedule_type  \
# 13   New York, NY              via LinkedIn         Full-time
# 126  New York, NY              via LinkedIn         Full-time
# 177  New York, NY              via LinkedIn         Full-time
# 230  New York, NY  via Redstream Technology         Full-time
# 502  New York, NY          via ZipRecruiter         Full-time
#
#      job_work_from_home          search_location     job_posted_date  \
# 13                False     Texas, United States 2023-11-15 13:08:52
# 126               False  New York, United States 2023-05-08 13:08:15
# 177               False  Illinois, United States 2023-12-22 13:06:34
# 230               False  New York, United States 2023-06-25 13:00:01
# 502               False  New York, United States 2023-10-18 13:00:14
#
#      job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 13                    True                  True  United States         NaN
# 126                  False                  True  United States         NaN
# 177                  False                 False  United States         NaN
# 230                  False                 False  United States         NaN
# 502                   True                 False  United States         NaN
#
#      salary_year_avg  salary_hour_avg  \
# 13               NaN              NaN
# 126              NaN              NaN
# 177              NaN              NaN
# 230              NaN              NaN
# 502              NaN              NaN
#
#                                         company_name  \
# 13                                             Nayya
# 126                           Career Search Partners
# 177  New York City Office of Technology & Innovation
# 230                             RedStream Technology
# 502                                        Arsenault
#
#                                             job_skills  \
# 13   ['python', 'sql', 'go', 'ruby', 'ruby', 'javas...
# 126  ['sql', 'python', 'sql server', 'excel', 'flow...
# 177  ['java', 'python', 'r', 'gcp', 'aws', 'azure',...
# 230    ['sql', 'excel', 'visio', 'powerpoint', 'word']
# 502                  ['sql', 'excel', 'microstrategy']
#
#                                        job_type_skills job_posted_month
# 13   {'cloud': ['aws'], 'other': ['terraform'], 'pr...              Nov
# 126  {'analyst_tools': ['excel'], 'databases': ['sq...              May
# 177  {'cloud': ['gcp', 'aws', 'azure'], 'libraries'...              Dec
# 230  {'analyst_tools': ['excel', 'visio', 'powerpoi...              Jun
# 502  {'analyst_tools': ['excel', 'microstrategy'], ...              Oct

# %%
df_NY.to_excel('new_york_jobs.xlsx', index=False)
