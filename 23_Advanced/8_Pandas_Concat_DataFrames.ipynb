# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt

# Loading data

df = pd.read_csv("D:/Python/Luke Barousse course/Python-for-Data-Analysis/20_Pandas/data_jobs.csv")

# data cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# #### Notes
#
# * `concat()`: Combine DataFrames by rows (axis = 0) or columns (axis=1).
# * Sticks the DataFrames together without using any keys.

# %% [markdown]
# ### Simple examples

# %%
# Sample dataset of job postings in January
job_postings_jan = pd.DataFrame({
    'job_id': [1, 2, 3, 4, 5],
    'job_title': ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Scientist', 'Data Engineer'],
    'company': ['Company A', 'Company B', 'Company C', 'Company D', 'Company E'],
    'job_posted_date': pd.to_datetime(['2024-01-02', '2024-01-07', '2024-01-14', '2024-01-19', '2024-01-24'])
})

job_postings_jan
# Out:
#    job_id                  job_title    company job_posted_date
# 0       1             Data Scientist  Company A      2024-01-02
# 1       2               Data Analyst  Company B      2024-01-07
# 2       3  Machine Learning Engineer  Company C      2024-01-14
# 3       4             Data Scientist  Company D      2024-01-19
# 4       5              Data Engineer  Company E      2024-01-24

# %%
# Sample dataset of job postings in February
job_postings_feb = pd.DataFrame({
    'job_id': [6, 7, 8, 9, 10],
    'job_title': ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Scientist', 'Data Engineer'],
    'company': ['Company F', 'Company G', 'Company H', 'Company I', 'Company J'],
    'job_posted_date': pd.to_datetime(['2024-02-05', '2024-02-09', '2024-02-12', '2024-02-18', '2024-02-22'])
})

job_postings_feb
# Out:
#    job_id                  job_title    company job_posted_date
# 0       6             Data Scientist  Company F      2024-02-05
# 1       7               Data Analyst  Company G      2024-02-09
# 2       8  Machine Learning Engineer  Company H      2024-02-12
# 3       9             Data Scientist  Company I      2024-02-18
# 4      10              Data Engineer  Company J      2024-02-22

# %%
# Concatenate the two dataframes

pd.concat([job_postings_jan, job_postings_feb])
# Out:
#    job_id                  job_title    company job_posted_date
# 0       1             Data Scientist  Company A      2024-01-02
# 1       2               Data Analyst  Company B      2024-01-07
# 2       3  Machine Learning Engineer  Company C      2024-01-14
# 3       4             Data Scientist  Company D      2024-01-19
# 4       5              Data Engineer  Company E      2024-01-24
# 0       6             Data Scientist  Company F      2024-02-05
# 1       7               Data Analyst  Company G      2024-02-09
# 2       8  Machine Learning Engineer  Company H      2024-02-12
# 3       9             Data Scientist  Company I      2024-02-18
# 4      10              Data Engineer  Company J      2024-02-22

# %%
# we notice that now the index repeats. we can ignore the index so it gets reset
pd.concat([job_postings_jan, job_postings_feb], ignore_index=True)
# Out:
#    job_id                  job_title    company job_posted_date
# 0       1             Data Scientist  Company A      2024-01-02
# 1       2               Data Analyst  Company B      2024-01-07
# 2       3  Machine Learning Engineer  Company C      2024-01-14
# 3       4             Data Scientist  Company D      2024-01-19
# 4       5              Data Engineer  Company E      2024-01-24
# 5       6             Data Scientist  Company F      2024-02-05
# 6       7               Data Analyst  Company G      2024-02-09
# 7       8  Machine Learning Engineer  Company H      2024-02-12
# 8       9             Data Scientist  Company I      2024-02-18
# 9      10              Data Engineer  Company J      2024-02-22

# %% [markdown]
# Let's go back to our data
# - we have one dataset
# - we have multiple months, we can create some datasets so we can practice concat

# %%
# starting by creating a column to identify the month

df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
# now we have to break this up into 12 dataframes
# the easiest way to do this is to store it in a dictionary

'''dict_months = {
    'Jan': df_jan,
    'Feb': df_feb,
    'Mar': df_mar,
    'Apr': df_apr,
    'May': df_may,
    'June': df_june,
    'Jul': df_jul,
    'Aug': df_aug,
    'Sep': df_sep,
    'Oct': df_oct,
    'Nov': df_nov,
    'Dec': df_dec
}
'''

# first we need to get a list of all the months
months = df['job_posted_month'].unique()

months
# Out:
# array(['Jun', 'Jan', 'Oct', 'Jul', 'Aug', 'Nov', 'Mar', 'Dec', 'Apr',
#        'Feb', 'Sep', 'May'], dtype=object)

# %%
# now e can start to build the dictionary comprehension

{month: month for month in months}
# Out:
# {'Jun': 'Jun',
#  'Jan': 'Jan',
#  'Oct': 'Oct',
#  'Jul': 'Jul',
#  'Aug': 'Aug',
#  'Nov': 'Nov',
#  'Mar': 'Mar',
#  'Dec': 'Dec',
#  'Apr': 'Apr',
#  'Feb': 'Feb',
#  'Sep': 'Sep',
#  'May': 'May'}

# %%
# but we want the dataframes as the values

{month:df[df['job_posted_month'] == month] for month in months}
# Out:
# {'Jun':                   job_title_short  \
#  0            Senior Data Engineer
#  8                Business Analyst
#  16                  Data Engineer
#  17                 Data Scientist
#  24                 Data Scientist
#  ...                           ...
#  785347             Data Scientist
#  785571               Data Analyst
#  785617               Data Analyst
#  785669  Machine Learning Engineer
#  785675               Data Analyst
#
#                                                  job_title  \
#  0       Senior Clinical Data Engineer / Principal Clin...
#  8                Technology & Operations Business Analyst
#  16                                      Big Data Engineer
#  17                                 Data Science Team Lead
#  24                          Data Scientist (DataLab Team)
#  ...                                                   ...
#  785347                    Practicante Científico de Datos
# ...

# %%
# it shows the jobs associated with a certain month
# let's assign it to a variable so then we can call it

dict_months =  {month:df[df['job_posted_month'] == month] for month in months}
dict_months['Jan']
# Out:
#           job_title_short                                  job_title  \
# 1            Data Analyst                               Data Analyst
# 20         Data Scientist                             Data Scientist
# 39          Data Engineer                              Data Engineer
# 53          Data Engineer                              Data Engineer
# 55         Data Scientist                             Data Scientist
# ...                   ...                                        ...
# 785699  Software Engineer                        Simulation Engineer
# 785700      Data Engineer                       Data Engineer Ssr/Sr
# 785703       Data Analyst    Data Analyst - CRYPTOGRAPHY - Full-time
# 785704   Business Analyst                           Business Analyst
# 785705       Data Analyst  Expert Business Data Analyst - Now Hiring
#
#                                  job_location             job_via  \
# 1                Guadalajara, Jalisco, Mexico    via BeBee México
# ...

# %% [markdown]
# ### Ask: we need Quarter  1 data

# %%
df_q1 = pd.concat([dict_months['Jan'], dict_months['Feb'], dict_months['Mar']], ignore_index=True)

# %%
df_q1
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
# ...

# %%
# we don't know if this is showing up correctly so we want to inspect it
df_q1['job_posted_month'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Concatenate two DataFrames to analyze job postings for Data Scientists and Data Analysts:
#
# Create one DataFrame with job postings for Data Scientists named data_scientist_df and another for Data Analysts named data_analyst_df.
# Concatenate them and display the combined DataFrame called combined_df.

# %%
data_scientist_df = df[df['job_title_short'] == 'Data Scientist'].copy()
data_scientist_df.head()
# Out:
#    job_title_short                                          job_title  \
# 9   Data Scientist                                  Data Scientist II
# 17  Data Scientist                             Data Science Team Lead
# 19  Data Scientist                                     Data Scientist
# 20  Data Scientist                                     Data Scientist
# 21  Data Scientist  Stage - data scientist – génération ia de donn...
#
#                   job_location  \
# 9                     Anywhere
# 17                  Laurel, MD
# 19    Pune, Maharashtra, India
# 20           Zaventem, Belgium
# 21  Asnières-sur-Seine, France
#
#                                               job_via job_schedule_type  \
# 9                                    via ZipRecruiter         Full-time
# 17  via APL Careers - Johns Hopkins University App...         Full-time
# 19                                         via Indeed         Full-time
# ...

# %%
data_analyst_df = df[df['job_title_short'] == 'Data Analyst'].copy()
data_analyst_df.head()
# Out:
#    job_title_short                                          job_title  \
# 1     Data Analyst                                       Data Analyst
# 12    Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18    Data Analyst                                       Data Analyst
# 31    Data Analyst                           Stage - Data Analyst F/H
# 34    Data Analyst  Data Analyst als Marketing Manager Automation ...
#
#                     job_location                          job_via  \
# 1   Guadalajara, Jalisco, Mexico                 via BeBee México
# 12                  Lyon, France                     via Jobijoba
# 18                Warsaw, Poland            via Praca Trabajo.org
# 31                 Paris, France                     via LinkedIn
# 34             Erlangen, Germany  via Central Illinois Proud Jobs
#
#            job_schedule_type  job_work_from_home search_location  \
# 1                  Full-time               False          Mexico
# ...

# %%
combined_df_DA_DS = pd.concat([data_scientist_df, data_analyst_df], ignore_index=True)
combined_df_DA_DS
# Out:
#        job_title_short                                          job_title  \
# 0       Data Scientist                                  Data Scientist II
# 1       Data Scientist                             Data Science Team Lead
# 2       Data Scientist                                     Data Scientist
# 3       Data Scientist                                     Data Scientist
# 4       Data Scientist  Stage - data scientist – génération ia de donn...
# ...                ...                                                ...
# 368356    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 368357    Data Analyst          Expert Business Data Analyst - Now Hiring
# 368358    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 368359    Data Analyst                 Data & Analytics Architect (w/m/x)
# 368360    Data Analyst                                   CRM Data Analyst
#
#                       job_location  \
# 0                         Anywhere
# ...

# %% [markdown]
# Concatenate DataFrames to analyze job postings by month:
#
# Create DataFrames for job postings for the last quarter (October, November, and December). These are respectively called oct_df, nov_df, and dec_df.
# Concatenate them and display the combined DataFrame named combined_df.

# %%
combined_sf_q4 = pd.concat([dict_months['Oct'], dict_months['Nov'], dict_months['Dec']], ignore_index=True)

# %%
combined_sf_q4
# Out:
#          job_title_short                                          job_title  \
# 0          Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 1          Data Engineer                                      Data Engineer
# 2           Data Analyst                                       Data Analyst
# 3           Data Analyst                           Stage - Data Analyst F/H
# 4           Data Analyst  Data Analyst (Bangkok Based, relocation provided)
# ...                  ...                                                ...
# 187359     Data Engineer                                      Data Engineer
# 187360     Data Engineer                                      Data Engineer
# 187361      Data Analyst                                  Data Analyst Lead
# 187362  Business Analyst         Business Analysis and Intelligence Manager
# 187363    Cloud Engineer                             Engineer 3, Facilities
#
# ...

# %%
combined_sf_q4['job_posted_month'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Concatenate DataFrames to analyze job postings for different job types:
#
# Create DataFrames for 'Full-time' roles (called full_time_df) and 'Part-time' roles (called part_time_df) job postings.
# Concatenate them and display the combined DataFrame named combined_df.

# %%
full_time_df = df[df['job_schedule_type'] == 'Full-time'].copy()
full_time_df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
part_time_df = df[df['job_schedule_type'] == 'Part-time'].copy()
part_time_df
# Out:
#              job_title_short  \
# 123             Data Analyst
# 303     Senior Data Engineer
# 367           Data Scientist
# 480             Data Analyst
# 494           Data Scientist
# ...                      ...
# 784405         Data Engineer
# 784594  Senior Data Engineer
# 784924        Data Scientist
# 785232      Business Analyst
# 785332        Data Scientist
#
#                                                 job_title        job_location  \
# 123     Data Analytics work from home job/internship a...            Anywhere
# 303     Senior Data Engineers (w/m/d). Job in Berlin M...     Berlin, Germany
# 367     ML & Data Science - Working Student - B2B Solu...            Anywhere
# 480     Data Analyst Bootcamp and Project Work  (remot...      Minsk, Belarus
# 494     Data Science (NLP Research and Analytics) work...            Anywhere
# ...                                                   ...                 ...
# ...

# %%
combined_df_job_type = pd.concat([full_time_df, part_time_df], ignore_index=True)
combined_df_job_type
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 709603         Data Engineer
# 709604  Senior Data Engineer
# 709605        Data Scientist
# 709606      Business Analyst
# 709607        Data Scientist
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 709603                                     Data Engineer*
# 709604                               Senior Data Engineer
# 709605     Математик, Junior/Middle/Senior Data Scientist
# ...

# %%
combined_df_job_type['job_schedule_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: >
